# %% [markdown]
# ## This topic should learn before learning the optimizers.

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('6-DailyDelhiClimateTest.csv',usecols=['date','meantemp'])

# %%
df.shape
# Out:
# (114, 2)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['date'],df['meantemp'],c='b')
plt.show()

# %%
x = df['meantemp'].ewm(alpha=0.4).mean()
x
# Out:
# 0      15.913043
# 1      17.529891
# 2      17.316228
# 3      17.952153
# 4      18.141577
#          ...
# 109    33.509863
# 110    33.805918
# 111    33.443551
# 112    33.216130
# 113    32.729678
# Name: meantemp, Length: 114, dtype: float64

# %%
df['ewm'] = x 
df
# Out:
#            date   meantemp        ewm
# 0    2017-01-01  15.913043  15.913043
# 1    2017-01-02  18.500000  17.529891
# 2    2017-01-03  17.111111  17.316228
# 3    2017-01-04  18.700000  17.952153
# 4    2017-01-05  18.388889  18.141577
# ..          ...        ...        ...
# 109  2017-04-20  34.500000  33.509863
# 110  2017-04-21  34.250000  33.805918
# 111  2017-04-22  32.900000  33.443551
# 112  2017-04-23  32.875000  33.216130
# 113  2017-04-24  32.000000  32.729678
#
# [114 rows x 3 columns]

# %%
plt.scatter(df['date'],df['meantemp'],c='b')
plt.plot(df['date'],x,c='black')
plt.show()
