# %%
import numpy as np
import pandas as pd

# %%
import tensorflow
import keras

# %%
from keras.datasets import imdb

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data(num_words=10000)

# %%
from keras.layers import Dense,SimpleRNN

# %%
X_train.shape
# Out:
# (25000,)

# %%
df = pd.DataFrame(X_train,columns=['review'])
df['sentiment'] = y_train
df.head(3)
# Out:
#                                               review  sentiment
# 0  [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, ...          1
# 1  [1, 194, 1153, 194, 8255, 78, 228, 5, 6, 1463,...          0
# 2  [1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 5...          0

# %%
len(df.iloc[0,0])
# Out:
# 218

# %%
from keras.utils import pad_sequences

# %%
X_train = pad_sequences(X_train, maxlen=500, padding="post")
X_test  = pad_sequences(X_test,  maxlen=500, padding="post")

# %%
print(len(X_train[0]))
print(len(X_train[1]))
# all shape beccome same
# Out:
# 500
# 500

# %%
set1 = set()

for sentence in X_train:
    for word in sentence:
        set1.add(word)

# %%
print(f"No of unique words are: {len(set1)}")
# Out:
# No of unique words are: 9999

# %%
from keras import Sequential

# %%
model = Sequential()

# %%
model.add(Embedding(input_dims=len(set1),output_dims = 32,input_length=len(X_train[1]))))
model.add(SimpleRNN(28))
model.add(Dense(1,activation='sigmoid'))
