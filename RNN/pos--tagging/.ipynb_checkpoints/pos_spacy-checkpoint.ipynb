# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp("I hello this is google")

# %%
doc
# Out:
# I hello this is google

# %%
doc[0]
# Out:
# I

# %%
doc[0].pos_
# Out:
# 'PRON'

# %%
spacy.explain('PRON')
# Out:
# 'pronoun'

# %%
for word in doc:
    print(word,'-->',word.pos_,spacy.explain(word.pos_))
# Out:
# I --> PRON pronoun
# hello --> INTJ interjection
# this --> PRON pronoun
# is --> AUX auxiliary
# google --> NOUN noun
