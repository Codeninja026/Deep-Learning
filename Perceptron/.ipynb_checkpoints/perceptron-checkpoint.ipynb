# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=100,n_features=2,n_informative=2,n_redundant=0,class_sep=1.0, 
                         n_clusters_per_class=1,n_classes=2,random_state=30)

# %%
df = pd.DataFrame(X,columns=['col1','col2'])
df['target'] = y
df
# Out:
#         col1      col2  target
# 0  -1.568188  0.833720       1
# 1  -0.359052 -0.443802       0
# 2  -0.847848  3.821559       1
# 3  -0.063649 -0.296111       0
# 4  -0.453137 -0.308114       0
# ..       ...       ...     ...
# 95  0.072033 -0.190499       0
# 96  0.548349  0.454336       0
# 97 -1.490778 -1.205109       0
# 98 -0.850431 -0.759152       1
# 99  0.334368  0.552633       1
#
# [100 rows x 3 columns]

# %%
plt.scatter(df.iloc[:,0],df.iloc[:,1],c=y,cmap='RdYlGn')

# %%
# cgpa	iq	placement
sns.scatterplot(x=df.iloc[:,0],y=df.iloc[:,1],hue=df['target'])
# Out:
# <Axes: xlabel='col1', ylabel='col2'>

# %%
from sklearn.linear_model import Perceptron

# %%
p = Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[-4.64351517,  5.69898256]])

# %%
p.intercept_
# Out:
# array([-2.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X=X,y=y,clf=p)
# Out:
# <Axes: >
